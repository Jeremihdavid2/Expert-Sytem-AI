# %%
# Insatlling world bank data
# !pip install wbdata
# !pip install wbgapi
# !pip install world_bank_data --upgrade

# %%
import numpy as np
import pandas as pd
import wbgapi as wb
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Choosing random countries of interest

# %%
# Choose 30 of random counries around the world
countries = ['Albania', 'Algeria', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 
            'Belarus', 'Belgium', 'Bolivia', 'Brazil', 'British Virgin Islands', 
            'Brunei', 'Bulgaria', 'Cameroon', 'Canada', 'Chad', 'Chile', 'China', 
            'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Falkland Island', 
            'Fiji', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Kenya', 'Kiribati']

# Get the country codes into dictionary, Key => country code, Value => Country name
country_codes = {
    'ALB'	: 'Albania',
    'DZA'	: 'Algeria',
    'BHS'	: 'Bahamas, The',
    'BHR'	: 'Bahrain',
    'BGD'	: 'Bangladesh',
    'BRB'	: 'Barbados',
    'BLR'	: 'Belarus',
    'BEL'	: 'Belgium',
    'BOL'	: 'Bolivia',
    'BRA'	: 'Brazil',
    'VGB'	: 'British Virgin Islands',
    'BRN'	: 'Brunei',
    'BGR'	: 'Bulgaria',
    'CMR'	: 'Cameroon',
    'CAN'	: 'Canada',
    'TCD'	: 'Chad',
    'CHL'	: 'Chile',
    'CHN'	: 'China',
    'DNK'	: 'Denmark',
    'DJI'	: 'Djibouti',
    'DMA'	: 'Dominica',
    'DOM'	: 'Dominican Republic',
    'FLK'	: 'Falkland Island',
    'FJI'	: 'Fiji',
    'ISR'	: 'Israel',
    'ITA'	: 'Italy',
    'JPN'	: 'Japan',
    'KAZ'	: 'Kazakhstan',
    'KEN'	: 'Kenya',
    'KIR'	: 'Kiribati'
}

# %% [markdown]
# Setting the indicator of intrest.

# %%
indicator = 'SP.DYN.LE00.FE.IN'

# Check indicator name
wb.series.info(indicator)
# Out:
# id                 value
# -----------------  ----------------------------------------
# SP.DYN.LE00.FE.IN  Life expectancy at birth, female (years)
#                    1 elements

# %%
# Loading the data
data = wb.data.DataFrame(indicator, country_codes, mrv=20, labels = True).set_index('Country')
data
# Out:
#                         YR2001  YR2002  YR2003  YR2004  YR2005  YR2006  \
# Country
# Kiribati                66.309  66.656  67.001  67.345  67.696  68.061
# Kenya                   53.434  53.837  54.535  55.497  56.667  57.969
# Kazakhstan              71.300  71.600  71.500  72.000  71.800  72.000
# Japan                   84.900  85.200  85.330  85.590  85.490  85.810
# Italy                   83.200  83.200  82.800  83.700  83.600  84.100
# Israel                  81.200  81.500  81.800  82.400  82.200  82.500
# Fiji                    67.616  67.736  67.830  67.895  67.938  67.972
# Dominican Republic      72.779  73.076  73.372  73.664  73.951  74.229
# Dominica                   NaN  78.800     NaN     NaN     NaN     NaN
# Djibouti                58.653  58.751  58.914  59.149  59.449  59.800
# Denmark                 79.200  79.200  79.500  79.900  80.200  80.400
# China                   73.674  73.951  74.237  74.535  74.845  75.170
# ...
